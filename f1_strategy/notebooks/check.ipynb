# %%
import pandas as pd
import pyarrow  # Required for reading Parquet files
import matplotlib.pyplot as plt

# %%
df1 = pd.read_parquet("../data/raw/race_control/season=2023/event=Bahrain_Grand_Prix/part.parquet")

df2 = pd.read_parquet("../data/raw/laps/season=2023/event=Bahrain_Grand_Prix/part.parquet")

df3 = pd.read_parquet("../data/raw/results/season=2023/event=Bahrain_Grand_Prix/part.parquet")

df4 = pd.read_parquet("../data/raw/weather/season=2023/event=Bahrain_Grand_Prix/part.parquet")

print("Race_control",df1.columns,sep='\n')
print(df2.columns)
print(df3.columns)
print(df4.columns)
# Out:
# Race_control
# Index(['Time', 'Category', 'Message', 'Status', 'Flag', 'Scope', 'Sector',
#        'RacingNumber', 'Lap', 'season', 'event_name', 'round_number',
#        'session_name', 'session_date'],
#       dtype='object')
# Index(['Time', 'Driver', 'DriverNumber', 'LapTime', 'LapNumber', 'Stint',
#        'PitOutTime', 'PitInTime', 'Sector1Time', 'Sector2Time', 'Sector3Time',
#        'Sector1SessionTime', 'Sector2SessionTime', 'Sector3SessionTime',
#        'SpeedI1', 'SpeedI2', 'SpeedFL', 'SpeedST', 'IsPersonalBest',
#        'Compound', 'TyreLife', 'FreshTyre', 'Team', 'LapStartTime',
#        'LapStartDate', 'TrackStatus', 'Position', 'Deleted', 'DeletedReason',
#        'FastF1Generated', 'IsAccurate', 'season', 'event_name', 'round_number',
#        'session_name', 'session_date'],
#       dtype='object')
# Index(['DriverNumber', 'BroadcastName', 'Abbreviation', 'DriverId', 'TeamName',
#        'TeamColor', 'TeamId', 'FirstName', 'LastName', 'FullName',
# ...
